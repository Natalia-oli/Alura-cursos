# %% [markdown]
# # Informações de fontes gerais

# %% [markdown]
# Em negócios, a analítica tradicional é usada principalmente para apoiar
# decisões internas nas organizações – questões como “Qual deve ser o preço deste
# produto?” ou “Que promoção de vendas mais tenderá a levar os clientes a
# comprar nossos produtos?”
#
#
# A analítica em ambientes de Big Data geralmente se
# presta a apoiar decisões sobre novos produtos ou novos recursos para os clientes
# – como o algoritmo PageRank, de busca no Google; o recurso “Pessoas que
# talvez você conheça”, no site da rede social LinkedIn; ou o desenvolvimento de
# novos jogos na Zynga.
#
# Caso a questão seja pouco importante ou envolva
# preferências pessoais, não se dê ao trabalho de coletar ou de analisar dados. Se a
# decisão for urgente, talvez não haja tempo para adotar abordagem analítica. E na
# hipótese de a decisão ser singular ou não repetitiva, talvez não se justifiquem os
# custos de reunir dados e de construir um modelo analítico. As decisões que mais
# se beneficiam com a analítica, portanto, são as que se repetem; que não são
# prementes, admitindo análises; e que são bastante importantes para justificar o
# investimento.

# %% [markdown]
# ANÁLISE QUANTITATIVA
#
# **Três estágios do raciocínio analítico e como aplicá-los**
#
# - **formulação do problema**:
#     - Reconhecimento do problema:
#         - situações que levam ao rec.: curiosidade, exp no trabalho, teorias.
#         - O padrão de evidências a essa altura é baixo. Evidentemente, toda a
# questão da análise quantitativa consiste em analisar alguns dados e testar o
# palpite. *Essa é a diferença entre pensadores analíticos e outros: os pensadores
# analíticos testam os palpites com base em dados e análises.*
#         - COMPREENDER PLENAMENTE A QUESTÃO E SUA IMPORTÂNCIA.
#         - saber quem são os stakeholders (partes interessadas/donos) e como se sentem em relação ao problema
#         - perguntas a serem respondidas:
#         - **Se não for possível responder afirmativamente à maioria das perguntas, o projeto talvez
# enfrente dificuldades desde o começo**:
# Resta alguma dúvida sobre que executivos têm interesse no sucesso do projeto de análise quantitativa?
# Foram os executivos informados sobre o problema e sobre o esboço da solução?
# Estão eles preparados para oferecer os recursos imprescindíveis e para promover as
# mudanças indispensáveis ao sucesso do projeto?
# Em geral, apoiam eles o uso de analítica e de dados como ferramentas na tomada de
# decisões?
# Coincidem a abordagem analítica e o método de comunicação propostos com a
# maneira típica de pensar e de decidir dos executivos?
# Dispõe você de um plano para promover feedback regular e para divulgar resultados
# intermediários aos executivos?
#       - Se você estiver convencido da necessidade de manejo dos stakeholders em
# seu projeto analítico, alguns dos componentes comuns desse processo são:**
# Identificar todos os stakeholders.
# Registrar as necessidades dos stakeholders.
# Avaliar e analisar os interesses e influências dos stakeholders.
# Administrar as expectativas dos stakeholders. Tomar providências.
# Revisar o status e repetir.
#   - Mesmo os projetos analíticos mais rigorosos e
# mais blindados serão pouco proveitosos se não induzirem à ação os responsáveis
# pelas decisões.
#     -É útil no passo de reconhecimento do problema concentrar-se
# nas decisões específicas a serem tomadas em consequência da análise.
#
#   - ESCOPO DO PROBLEMA:as histórias baseadas em dados e as análises quantitativas
# subjacentes não raro apresentam escopo um tanto estreito, porque exigem coleta e aplicação de dados a hipóteses sujeitas a testes
#   - É difícil reunir dados sobre problemas muito amplos,
# mas é importante, a essa altura, não limitar prematuramente o escopo do problema ou decisão.
#   - Por exemplo, se uma empresa identifica um problema de desempenho em determinada unidade de negócios ou área geográfica, é importante manter-se aberto para vasta diversidade de causas – desde insatisfação dos clientes até ineficiências operacionais, passando por deficiências nos produtos e serviços.
#   - Seja específico sobre o que quer descobrir
#   - Embora seja importante raciocinar com amplitude no começo do passo de reconhecimento do problema, ao concluí-lo será necessário ter criado uma descrição clara da questão, com definições concretas dos principais itens ou variáveis a serem estudados.
#
#   - ReVISÃO DAS DESCOBERTAS ANTERIORES:Neste passo, basicamente, perguntamos: “Já se contou antes história semelhante a esta?” Em caso positivo, podemos extrair ideias do trabalho realizado no passado. A revisão das descobertas anteriores pode sugerir os seguintes questionamentos:
#     - Que histórias contaremos? Envolverão essas narrativas previsões,
#     - relatórios, experimentos e pesquisas?
#     - Que dados deveremos procurar?
#     - Como as variáveis foram definidas antes?
#     - Que espécies de análises tenderemos a executar?
#     - Como contaremos história mais interessante, diferente das anteriores, mais propensa a produzir resultados?
#     - Um dos principais atributos da análise quantitativa (e do método científico,
# em termos mais amplos) é basear-se em pesquisas e descobertas anteriores. Por
# exemplo, a busca de informações sobre problemas correlatos, em livros, relatórios e artigos, é muito importante para chegar ao âmago do problema. Os resultados talvez ajudem a identificar variáveis relevantes e associações entre elas.
#   - Em analítica, não se pode fazer algo a partir do nada.
# Só é possível resolver um problema quando se tem domínio total das descobertas
# anteriores
#     - Hoje, usando motores de busca como Google, é possível
# compilar vasto material relacionado com a sua questão. Organizando e avaliando
# o material, é possível identificar modelo ou abordagem potencial para resolver o
# problema.
#   - NA REVISÃO  Talvez se constate que é necessário modificar a
# história, o escopo do problema, a decisão e até os stakeholders. Em seguida, mudando ou preservando as condições iniciais, o estágio de formulação do problema estará concluído e se avançará para a solução do problema, usando métodos de análise quantitativa.
# ---
# A distribuição de Poisson expressa a probabilidade de
# numerosos eventos acontecerem em determinado período, área ou volume, caso
# as ocorrências se repitam conforme certos padrões
# ---

# %% [markdown]
# SOLUÇÃO DE PROBLEMAS
#
#
# modelos: Simplificada denota que precisamos omitir todos os
# detalhes desnecessários e triviais e isolar os atributos importantes, úteis e
# cruciais que fazem diferença.
#
#
# **Como selecionar as variáveis e descobrir como elas se relacionam umas com as outras?**
# - Hipóteses –
# as primeiras histórias que se contam sobre a análise – são apenas palpites
# elaborados sobre as variáveis realmente importantes para o modelo.
#   - Nesse
# estágio, a construção de modelos exige o uso da lógica, da experiência e das
# descobertas anteriores para formular hipóteses sobre a variável dependente –
# aquela que se tenta prever ou explicar – e sobre as variáveis independentes que
# a afetarão
#
#
# MODELAGEM:
# - escolha de variáveis que façam sentido para a resolução do problema.
#
# PASSOS DA COLETA DE DADOS:
# - como medir as variaveis:
#     - variaveis categóricas: palvras que indicam categorias, como cor dos olhos, sabor do sorvete
#     - variaveis ordinais: aquelas as que atribuem número: concordo muito, pouco, quanto maior o número mais a variável está presente - escala de likert
#     - Variáveis numéricas (intervalo e razão): Essas variáveis têm números com unidades padronizadas, como peso em libras ou em quilos ou altura em tonelada ou em centímetros. Quanto maior é o número, mais a variável está presente.

# %% [markdown]
# **Que tipo de história analítica se está contando?**
#
# Tipos
#
# HISTÓRIAS CSI (INVESTIGAÇÃO CRIMINAL): descobrir causas de eventos.
#   - não exigem
# análises estatísticas profundas, bastando a compilação de dados e a elaboração
# de relatórios.
#
# HISTÓRIAS EURECA:
#   - São semelhantes às histórias CSI, a não ser pelo fato de, em
# geral, consistir em abordar de propósito determinado problema (em vez de
# deparar com o problema), no intuito de decidir importante mudança na
# estratégia ou no modelo da organização.
#   - Elas tendem a ser mais longevas,
# envolvendo mais análises ao longo do tempo.
#   - Às vezes, as histórias Eureca se
# associam a outros tipos de histórias de analítica, pelo simples fato de os
# resultados serem tão importantes para a organização.
#
# HISTÓRIAS DE CIENTISTA MALUCO:
#   - As histórias de cientista maluco se ajustam muito bem a certas organizações,
# como varejistas (com muitas lojas) e bancos (com muitas agências),
# características que facilitam o uso de algumas localidades para experimentos e de outras localidades para controles.
#
#
# HISTÓRIAS DE PESQUISAS:
#   - Pesquisas são método clássico de análise quantitativa.
# Os pesquisadores observam um fenômeno que já aconteceu ou que está
# acontecendo agora, sem manipular o resultado – apenas codificando-o e anali sando-o
#
#
# HISTÓRIAS DE PREDIÇÕES:
#   - Têm a ver com antecipar o que acontecerá. Embora
# seja muito difícil conseguir bons dados sobre o futuro, levantar dados históricos e compreender os fatores que impulsionaram os acontecimentos passados é algo muito objetivo e direto em análise quantitativa;
#   - Em geral, o processo é denominado analítica preditiva ou modelagem preditiva.
#   - Evidentemente, se os fatores que parecem prever algo não fazem nenhum sentido, é bom voltar atrás, verificar os dados e repetir a análise. Seja como for, a análise de dados pode efetivamente superar as previsões intuitivas na maioria das
# circunstâncias.
#   - Como advertência, lembre-se de que as histórias preditivas usam
# dados do passado para imaginar o futuro.
#   - Se algo no mundo mudar depois da análise, as previsões perdem a validade.
#
#
# HISTÓRIAS “EIS O QUE ACONTECEU”:
#   - As histórias que contam o que aconteceu com
# base em dados são talvez as mais comuns. Elas fornecem os fatos – quantos
# produtos foram vendidos, quando e onde, quais foram os resultados financeiros do último trimestre, quantas pessoas contratamos no ano passado.
#   -  Como apenas
# relatam fatos e não recorrem a matemática sofisticada, talvez pareça que é fácil
# contá-las.
#   -  Hoje, porém, o grande aumento no volume de dados existentes nas
# organizações acarretou aumento semelhante nas histórias baseadas em dados.
#   - Portanto, às vezes, é difícil atrair a atenção do público almejado para a ampla
# variedade de relatórios.
#   -  Talvez se constate que é necessário modificar a
# história, o escopo do problema, a decisão e até os stakeholders. Em seguida, mudando ou preservando as condições iniciais, o estágio de formulação do problema estará concluído e se avançará para a solução do problema, usando métodos de análise quantitativa.
#
# REFORMULAÇÃO DO PROBLEMA:
#   - Embora tenhamos apresentado o processo analítico de solução do problema
# como sequência linear de seis passos em três estágios, a abordagem deve ser,acima de tudo, iterativa. Cada passo lança nova luz sobre o problema e é sempre boa ideia pensar em como reconsiderar os passos anteriores sob novo enfoque. Embora não se deva reexaminar indefinidamente cada passo, sempre vale a pena refletir um pouco sobre o que a revisão das descobertas anteriores sugerem sobre a formulação do problema (a “Planilha de reformulação do problema” pode ser
# útil).
#
# **Planilha de reformulação do problema**
#   - Foi o problema bem formulado? Em caso positivo, deve ser possível responder afirmativamente à maioria das perguntas a seguir:
#     - Você definiu com clareza um problema ou oportunidade a fim de abordar o que é importante para a empresa ou organização?
# Você considerou várias maneiras alternativas de resolver o problema?
#   - Você identificou os stakeholders do problema e comunicou-se amplamente com eles sobre a questão?
#   - Você está confiante em que a maneira como pretende resolver o problema será satisfatória para os stakeholders e que eles usarão os resultados para tomar decisões?
#   - Você está seguro quanto às decisões a tomar – e sobre quem as tomará – com base nos resultados de sua análise, depois da solução do problema?
#   - Você começou com uma definição ampla do problema, mas depois o restringiu a aspectos muito específicos, com uma descrição muito objetiva da questão a ser abordada, dos dados a serem aplicados e dos resultados possíveis.
#   - Você é capaz de descrever o tipo de história analítica a ser contada para resolver este problema específico?
#   - Alguém é capaz de ajudá-lo a resolver esse tipo específico de história analítica?
#   - Você procurou sistematicamente descobertas ou experiências anteriores relacionadas com o problema, dentro ou fora da organização?
#   - Você reexaminou a definição do problema com base no que descobriu com a revisão das descobertas anteriores?

# %% [markdown]
# Hoje, contudo, as empresas podem
# recorrer à análise quantitativa para identificar as despesas com marketing
# eficazes e ineficazes – e para determinar a composição mais produtiva das
# despesas com marketing. Trata-se do que é tipicamente denominado **análise do
# mix de marketing**, cada vez mais popular entre empresas que vendem para
# consumidores.

# %% [markdown]
# Variável dependente: Variável cujo valor, por enquanto desconhecido, se quer prever ou
# explicar. Por exemplo, caso se queira predizer a qualidade de uma safra de vinho,
# usando a temperatura média no cultivo, a pluviosidade na colheita, a pluviosidade no
# inverno anterior e a antiguidade da safra, a qualidade da safra de vinho seria a variável
# dependente. Outros nomes são variável explicada e variável de resposta

# %% [markdown]
# # LIVRO: ESTÁTISTICA APLICADA A TODOS OS NÍVEIS
# #### Nelon Pereira Castanheira
# ---
#                       R E S U M O
# ---

# %% [markdown]
# ## Capítulo 2 - Apresentação dos dados
#
# - Os dados brutos são os resultantes de uma pesquisa e que foram transcritos aleatoriamente,sem qualquer ordem.
#   - originais
#   - não se encontram prontos para uma análise
#   - coloca-los em ordem é transforma-lós em um rol.
#
# - Frequência ou frequência absoluta é a quantidade de vezes que um valor aparece:
#   - distribuição de frequência: tabela com valores e com a quantidade de vezes que se repetem.
#
# - **Frequencia Absoluta acumulada ou frequencia acumulada(fa): é a somatória das frequências dos valores inferiores ou iguais ao valor do dado.**
#
# Tabelas
#   - cabeçalho: contém o suficiente para saber do que trata.
#   - corpo: constituído de linhas e colunas
#   - rodapé: informações que esclare informações a respeito dos dados: legendas, fonte.
#
#
#
# Classes ou intervalos
# l---- representa que o valor que está no limite inferior é incuido no intervalo, ao contrário do limite superior.
#   + limite superior - limite inferior = amplitude de um intervalo
#   + para evitar poluições ao a partir das tabelas criar gráficos é interessante que o numero MININO de intervalos/classes seja igual a 5. O número máximo não deve ultrapassar 20.
#
#
# Frequencia relativa
# fr = f/n, em que n é a soma de todos os f (sigma, Σ)

# %% [markdown]
# CAPITULO 5 - MEDIDAS DE DISPERSÃO
#
# são medidas que servem para verificar com que confiança as medidas de tendencia central resumem as informações fornecidas pelos dados obtidos em uma pesquisa.
#
#
# paara avaliar o grau de variedade(dispersão) dos valores de um conjunto de numeros é utilizado as medidas de dispersão absoluta, que permite ter um conhecimento mais completo dos dados. são elas:
#
# - amplitude toal ou intervalo total
# diferença entre menor e maior valor de uma serie
#
# para ddados agrupados em classes/intervalos: diferença entre a média(ponto médio) no valor superior menos a média do valor inferior ou pode ser feito pelos limites > limite superior da ultima classe menos limite inferior da primeira classe.
#
# - amplitude semi-interquartilica/desvio quadril
#
# - desvio médio:
#
# - variância
#
# - desvio padrão
#
# - momentos
#
# - coeficiente de variação de pearson

# %% [markdown]
# **series estatisticas**
# nome que se da a uma tabela na qual há  um critério distinto que a especifica e a diferencia.
#
# TIPOS DE SERIES:
# - temporais/cronológicas/evolutivas/históricas: variação do tempo, local e fato fixos.
# - geográficas: variação do local de ocorrência, tempo e fato(fenomeno) fixos.
# - especificas: variação do fato, local e tempo constantes. (ou seja, dados agrupados de acordo com a modalidade, sendo classificado também como uma distribuição de frequências)
# - conjulgadas/mistas: combinação entre series temporais, geográficas e mistas. Ou seja, varia o tempo, o local e o fato(fenômeno).
# - de distribuição de frequencia
#
#
# TIPOS DE GRÁFICOS E USOS:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Poligono de freqência:
# ![image.png](data:image/png;base64,...)
#
#
# é obtido unindo-se por segmentos de retas os pontos médios das bases superiores dos retangulos do histograma.

# %% [markdown]
# Mapa passado na momento com ifood que mostra gráficos para cada tipo de visualização:
#
# https://extremepresentation.typepad.com/files/choosing-a-good-chart-09.pdf

# %% [markdown]
# A média é válido utilizar quando os valores do conjunto são próximos.
#
# **Moda** - útil para histogramas
#
# **Mediana **- quando os valores são  muito dispersos, para saber o meio (50% do conjunto de dados vão até ali)

# %% [markdown]
# correlação: interdependência entre duas ou mais variáveis.
# Interdependência clara:
# Massa corporal e altura;
#   - Consumo de combustível e distância percorrida;
#   - Número de anúncios e produtos vendidos;
#   - Tempo de estudo e desempenho na avaliação(nem sempre…rs).
#
# Mas em muitos casos essa relação não é aparente, e assim devemos recorrer a métodos mais confiáveis de detecção: os índices de Pearson, Spearman e Kendall. Vamos falar um pouco sobre esses índices.
#
#
# correlação de person: só pode ser usada quando as variaveis são dependentes e quantitativas
#
#  “ρ de Pearson” (linear) -  mede o grau da correlação (e a direção dessa correlação — se positiva ou negativa) entre duas variáveis. Este coeficiente, normalmente representado por ρ assume apenas valores entre -1 e 1.
#
# - Interpretando o valor de ρ
#     - 0.9 a 1 positivo ou negativo indica uma correlação muito forte.
#     - 0.7 a 0.9 positivo ou negativo indica uma correlação forte.
#     - 0.5 a 0.7 positivo ou negativo indica uma correlação moderada.
#     - 0.3 a 0.5 positivo ou negativo indica uma correlação fraca.
#     - 0 a 0.3 positivo ou negativo indica uma correlação desprezível.
#
#   c. positiva interva        c.positiva direta
# - 1 ----------0------------ + 1
#   um desce e outro sobe       ambos sobem
#
# **Coeficiente de Correlação de Spearman**
#
# O coeficiente de correlação de Spearman é indicado para o cálculo da correlação entre variáveis aleatórias x e y relacionadas monotonicamente entre si, mas não necessariamente de maneira linear. Se a relação é linear o método de Pearson é o mais indicado
#
# - Precisa de duas variáveis: uma quantitativa X qualitativa ordinal(possui ordem) OU quando ambas são qualitativas ordinais.
#
# **Coeficiente de correlação tau de Kendall**
#
# Pares concordantes (x1,y1),(x2,y2) são os pares que obedecem às seguintes regras: x1< x2 e y1 < y2, ou x1 > x2 e y1 > y2. No exemplo os pares (4,6) e (5,9) nas linhas 3 e 4 são pares concordantes. Os pares (1,7) e (2,5), das linhas 0 e 1, não obedecem às regras e são chamados de discordantes.
#
#
#
# Correlação não implica causa!
#  - um estudante tem boas notas em física e química. Mas o bom desempenho em química não pode ser explicado pelo bom desempenho em física. As boas notas nessas disciplinas poderiam ser explicadas pelo bom desempenho em matemática, fator não considerado no primeiro momento.

# %% [markdown]
# De forma geral a correlação é mais uma ferramenta que pode nos auxiliar na construção de modelos mais confiáveis.
