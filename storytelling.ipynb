# %% [markdown]
# # Live: storytelling

# %% [markdown]
# " o sucesso da visualização de dados nao começa com a visualização"
#
# **01: importancia do contexto**
#  - quem será o público alvo
#  - pensar na relação que tem com o seu público
#  - eles te consideram especialista?
#  - qual fato é relevante, o que o pública precisa saber?
#  - porque seu público deve se importar com que você diz?
#       - colocar objetivo claramente
#  - em um email o nível de detalhamento deve ser alto
#  - quais dados disponiveis que ajudarão apresentar a ideia?
#  - considerar também os dados que nao confirmam a a hipotese em questão
#  -   "Sem dados voce é apenas uma pessoa com opinião"
#  - caso queiramos abranger todos os públicos de uma empresa, vai haver insatisfação
#       - Quem é o público, o que vamos transmitir, como vamos analisar os dados?
#
# *Quais informações para entender o contexto de análise:*
# - quais informações são relevantes ou fundamentais?
# - Quem é o público ou tomador de decisão? o que sabemos a respeito dele?
# - quais predisposições do nosso púnlico tem que posso faze-lo apoiar ou resistir a nossa mensagem?
#
# - quais dados disponíveis reforçariam nossa tese? o público conhece os dados?
# - quais fatores poderiam enfraquecer nossa tese e precisam ser olhadas com atenção?
# - o que seria um resultado bem-sucedido? qual a expectativa?
#    - análise alinhado com o que o público quer ver
#
#
#
# ---
#
# ### *Se você tivesse apenas um período de tempo limitado ou uma única frase para dizer ao seu público o que ele precisa saber, o que diria?*
#
# ---
#     3 metodologias para ter uma ideia do que é nossa apresentação/ideia central
#
#     Estratégia para passar a ideia:
#       - a história de 3 min: o que diria para a pessoa comprar a sua ideia
#       - Se ao inves de tres minutos, uma frase, qual seria:
#       - Storyboard: estabelecer uma estrutura para a apresentação
#
# **02: A escolha de um visual eficaz**
#
# - ter número não indica necessidade de gráfico
#     - uma unica frase destacando o número pode suprir.
# - tabelas: não deixa claro onde devemos focar
# - bordas grossos: focam a atenção no designer
# - minimizar o designer das tabelas - bordas
# - se for usar tabela, usar mapa de calor nela, com cores fortes e fracas em alguns valores mais relevantes
#    - ![image.png](data:image/png;base64,...)
# - gráficos de dispersão: colocar linha pontilhada onde os valores são acima da média
# - ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Gráfico de inclinação: usado para comparar valores de aumento/diminuição
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Gráfico de barras: apesar de ser comum, é muito importante. Também deixar o eixo no zero é necessário.
# - Gráfico de pizzas: Não deve ser utilizado.
# - Gráficos 3D: sobrecarga mental, não deixa claro
# - Gráfico com eixo y secundário: deve ser evitado para pessoas que não tem familiaridade com gráficos
# - Gráfico de radar: evitar usar
#
# *O que você precisa que seu público saiba?*
#
# **03: A saturação é sua inimiga:**
# - Deixar legenda de cores
# - nuvens de palavras são interessantes
# - muitas informações/cores: carga cognitiva excessiva
# - quanto menor a carga mental, melhor
# - saturação: elementos visuais que ocupam espaço, mas não aumentam o entendimento
# - Principios da Gestalt de percepção visual:
#   - objetos próximos assimilamos como parte de um grupo
#   - similaridade: objeto semelhantes são percebidos como pertencentes a parte de um grupo
#   -  acercamento: achamos que objetos fisicamente delimitados fazem parte de um grupo
#   - fechamentO: wusnfo partes de um todo estão faltaando, nossos olhos completam
#   - continuidade: nosso cerebro cria continuidade naturalmente
#   - conexão: tendemos a considerar objetos fisicamente conectados como parte de um grupo
#   - bordas são descessárias, muitas vezes
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# **04: Focalize a atenção do seu pública**
#
# - mudar algum detalhe da informação relevante
# - posição das informações nos slides também é importante
#
# ![image.png](data:image/png;base64,...)
#
# **Lições sobre storytelling**
#
# "há sempre uma história em seus dados, mas as ferramentas não sabem qual é essa história"
#
# **inicio**
# - quando e onde a historia ocorre?
# - O personagem princial
# - porque é necessário?
# - o que você quer que aconteça?
# - como vai provocar mudanças?
#
# **meio - convencer o público**
#
# - desenvolver melhor a situação
# - incorporar um contexto externo (ir atrás de outras informações para agregar)
# - dê exemplo, inclua dados que demosntrem o problema
# - o que acontece se nenhuma ação for tomada
# - discutir possíveis opções para tratar o problema
# - finalizar com uma chamada para ação (CHAMAR AS pessoas para comprar a sua ideia)

# %% [markdown]
# Pense como um designer:
#
# + as pessoas leem normalmente no padrão z
# + tendo coisas grandes, os olhos focam/leem primeiro
# + espaços em branco é importante
# + cores brilhantes destacam-se de cores cinzas e suaves

# %% [markdown]
# dicas - curso de visualização
# GRÁFICO DE SETORES:
# + ordenar os valores
# + destacar o que se deseja ver e colocar em cinza o resto
# + simplificar o gráfico, mantendo apenas as categorias que importam;
# + saber quais pontos destacar;
# + usar as cores mais apropriadas para a mensagem do gráfico;
# + mostrar o percentual das categorias:
# + nomear as categorias;
# + usar um título descritivo.
# + o titulo pode exprimir o que o gráfico mostra
#
#
#
# "Um bom titulo dispensa legendas"
#
#
# **No gráfico de barras, caso seja necessário destacar algo,é importante colocar em porcentagem por exemplo, para ficar explicito que as barras destacadas fazem parte do todo, ou colocar em porcentagem.**

# %% [markdown]
# Ao criar um dashboard, você está dizendo para seu usuário tirar suas próprias conclusões a partir dos gráficos que ele ver, e isso é muito perigoso, principalmente em painéis que oferecem opções self-service.
#
# Não use seus dashboards como relatório, e vice-versa
#
# é nosso dever nos policiar e entender se aquela pergunta que o cliente quer responder está realmente ligada a uma métrica de negócio, e se ela realmente precisar estar em um dashboard.
#
# Aplicações como Microsoft PowerBI, Qlik, Tableau, e até o nosso amado Metabase (doi meu coração dizer isso) são excelentes para facilitar e automatizar o processo de criação de um dashboard, mas elas se resumem a isso. Embora algumas dessas ferramentas permita que você inclua markdowns ou outros elementos de texto para enriquecer seu dashboard , elas limitarão seu trabalho a explicar o que significa um gráfico, ao invés de descrever hipóteses e sugerir conclusões. A boa notícia é que há soluções surgindo no mercado como a Arria: uma aplicação que utiliza Natural Language Generation para gerar storytelling de seus dados.
#
# Utilize dashboards para acompanhar indicadores-chave do negócio; crie análises para resolver problemas complexos, testar hipóteses e explorar uma nova visão sobre o problema/solução. Embora trabalhosa, o valor entregue por uma boa análise é muito melhor que qualquer dashboard colorido. Imagina perceber durante seu estudo que um usuário que se cadastra na plataforma após ver um vídeo no Youtube tem uma retenção muito maior que outros clientes? Será que essa informação está atrelhada a algum indicador do negócio? Se sim, faz todo sentido tê-la em um dashboard; se não, você garantiu uma nova visão ao seu cliente, no mínimo.

# %% [markdown]
# # Como criar seu próprio storytelling?

# %% [markdown]
# - Definir seu objetivo
# - Responder as perguntas? quem é meu público-alvo? É alguém que possui conhecimento técnico? É alguém que nunca viu um gráfico na vida
# - O que eu quero que essa pessoa entenda ao final do Storytelling? Se possível, escreva a resposta dessa pergunta e fixe em algum lugar, pois ela será seu guia durante todo o Storytelling.
# - Utilize bem o tempo que você terá. Seja direto e o mais sucinto possível para tirar o máximo da sua apresentação. Vale lembrar que um Storytelling pode ser desde uma apresentação do Power Point até um notebook no Jupyter. Independente da forma que apresentará, seja sábio.
# - Tentar usar uma linguagem técnica demais para um público leigo, assim como fazer quinze parágrafos para uma introdução é mais chato que pernilongo gordo. Se a ocasião permitir, seja descontraído e use uma linguagem mais informal — vale até GIF — ; se não permitir, seja simples e direto.
# -  É importante também destacar pontos negativos — ou pontos de atenção — da sua abordagem. Isso mostra que você não é arrogante o suficiente para achar que sua solução é a verdade absoluta.
# -Preparar algumas perguntas que poderão ser feitas e treinar suas respostas é um ótimo início. Leu uma parte do texto que acha que poderá acarretar em dúvida? Então provavelmente haverá mesmo. Treine sua resposta.
# - Outra interessante ação é apresentar seu trabalho para um colega de trabalho ou para outras pessoas, para que possam saber se sua linha de pensamento está clara e receber feedbacks sobre o Storytelling.

# %% [markdown]
# # Dicas de ferramentas
#
# -  D3.js: uma biblioteca de JavaScript para visualizações interativas. Caso procure por uma opção mais simples, mas ainda poderosa, você pode optar pelo Bokeh, Plot.ly ou o Folium, sendo este último usado para visualização usando mapas.
# - O Shorthand é uma ferramenta online que permite criar belos Storytelling de forma simples, rápida e sem necessidade de conhecimento em programação. Embora seja pago, o site oferece uma versão trial para que você possa criar aquele Storytelling especial.

# %% [markdown]
# # Dicas para visualizações mais acessíveis

# %% [markdown]
# - usar legendas diretas, ou seja, dentro do gráfico mesmo, em lcais mais estrátegicos
# - usar formas nas linhas
# - Use padrões e texturas em gráficos e mapas
# - Em geral, devemos evitar combinações entre:
# Vermelho & Verde
# Verde & Marrom
# Verde & Azul
# Azul & Cinza
# Azul & Roxo
# Verde & Cinza
# Verde & Preto
# - descrever o gráfico(texto que fica abaixo do gráfico): Tipo de gráfico
# Tipo de dado
# Propósito do gráfico
# Dados na íntegra
# - exemplo: "Descrição: Gráfico de barras que mostra o percentual dos tributos na arrecadação no Brasil. Cinco deles concentram 71% da arrecadação: ICMS (21%), IR (18), Cofins (16), Contra. à previdência (11), Contra. ao FGTS (5). Fonte: Receita Federal, “Carga Tributária no Brasil 2018”. Autoria: Insper

# %% [markdown]
# # Tipos de gráficos
#
# - Gráfico de área
#   - Os gráficos de área são ótimos para destacar oscilações de uma categoria de acordo com variáveis como o tempo. Se você precisa demonstrar a evolução das vendas de um produto ou o tempo de desenvolvimento de um projeto, por exemplo, esse é o modelo que pode representar melhor as informações.
#   -Um gráfico de área é basicamente um gráfico de linha, mas o espaço entre o eixo x e a linha é preenchido com uma cor ou padrão. É útil para mostrar relações de parte para todo, como mostrar a contribuição de representantes de vendas individuais para as vendas totais de um ano. Ajuda a analisar as informações gerais e individuais das tendências.
#
# - Gráfico de dispersão
#    - Um gráfico de dispersão ou gráfico de dispersão mostrará a relação entre duas variáveis ​​diferentes ou pode revelar as tendências de distribuição. Deve ser usado quando há muitos pontos de dados diferentes e você deseja destacar semelhanças no conjunto de dados. Isso é útil ao procurar outliers ou para compreender a distribuição de seus dados.

# %% [markdown]
# para usar quando quiser saber que tipo de gráfico plotar de acordo com o que quero:
# https://blog.hubspot.com/marketing/types-of-graphs-for-data-visualization
